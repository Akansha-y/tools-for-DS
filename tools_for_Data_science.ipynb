# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Akansha yadav
# Data Science Intern

# %% [markdown]
# *i am interested in data science because i would to contribute my efforts in IT firms in future and also i thinking in future the entire world will be driven by technology.*

# %% [markdown]
# ### The below code should print "Tools for Data Science-final Assessment"

# %%
print("Tools for Data Science-final Assessment")
# Out:
# Tools for Data Science-final Assessment

# %% [markdown]
# >adding blockquote in the paragraph.
#
# - unordered
# - list
# - number
#
#
# ![IBM watson studio !](data:image/png;base64,... "IBM watson studio")
#
#
#
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned | $1600 |
# | col 2 is      | centered      |   $12 |
# | zebra stripes | are neat      |    $1 |
